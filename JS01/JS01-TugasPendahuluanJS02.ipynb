# %% [markdown]
# <a href="https://colab.research.google.com/github/athfizh/PemMes26_05_Hafizh/blob/main/JS01/JS01-TugasPendahuluanJS02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # **Tugas Pendahuluan JS02**
#
#
# ---

# %% [markdown]
# Kumpulkan 30 data dari teman Anda (boleh dalam satu kelas) berisikan informasi berikut,
# 1. Nama Lengkap
# 2. Jenis Kelamin
# 3. Kota Asal
# 4. Tinggi Badan (cm)
# 5. Berat Badang (kg)
# 6. Asal Kelas (Kelas semester sebelumnya)
# 7. Target IPS (target realistis IPS semester ini)
#
# Rangkum data dalam format spreadsheet.

# %% [markdown]
# [Link Spreadsheet](https://docs.google.com/spreadsheets/d/1qIIBBLVWmUAasWcWK77Blrhz6rs7jDI72tAjGwxKwZM/edit?usp=sharing)
